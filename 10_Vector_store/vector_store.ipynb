# %%
pip install langchain-chroma chromadb
# Out:
# Collecting langchain-chroma
#   Using cached langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: chromadb in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (1.5.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from langchain-chroma) (1.4.7)
# Requirement already satisfied: numpy>=2.1.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from langchain-chroma) (2.4.6)
# Requirement already satisfied: build>=1.0.3 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.47.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (1.81.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (36.0.2)
# Requirement already satisfied: tenacity>=8.2.3 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.8.9)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.1.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.27.0->chromadb) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.27.0->chromadb) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from httpx>=0.27.0->chromadb) (3.15)
# Requirement already satisfied: h11>=0.16 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: pyproject_hooks in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2026.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from kubernetes>=28.1.0->chromadb) (2.7.0)
# Requirement already satisfied: durationpy>=0.7 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.2)
# Requirement already satisfied: flatbuffers in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.63b1)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from tokenizers>=0.13.2->chromadb) (1.17.0)
# Requirement already satisfied: click>=8.4.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.29.1)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\PRIYANSHU DEORA\AppData\Roaming\Python\Python314\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\Users\PRIYANSHU DEORA\Desktop\Langchain\venv\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Using cached langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Installing collected packages: langchain-chroma
# Successfully installed langchain-chroma-1.1.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored

# %%
from langchain_chroma import Chroma
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="mxbai-embed-large"
)

# %%
vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory='my_chroma_db',
    collection_name='sample'
)

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
# add documents
vector_store.add_documents(docs)
# Out:
# ['41fb4b03-b210-43d5-b819-47c05cf904d2',
#  '1abeba72-1b3e-4086-8324-e94d257f276a',
#  'f0b38b3f-e1c9-4db5-91a3-b3e06fe6c052',
#  'a7fd7709-13dd-45ef-8669-36f6002ccaf6',
#  'cf2462ea-6541-405b-8eaf-c0fbe4e9a5a4']

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['41fb4b03-b210-43d5-b819-47c05cf904d2',
#   '1abeba72-1b3e-4086-8324-e94d257f276a',
#   'f0b38b3f-e1c9-4db5-91a3-b3e06fe6c052',
#   'a7fd7709-13dd-45ef-8669-36f6002ccaf6',
#   'cf2462ea-6541-405b-8eaf-c0fbe4e9a5a4'],
#  'embeddings': array([[-0.00304607, -0.00076735, -0.01943563, ..., -0.01808811,
#           0.00222509, -0.01835713],
#         [ 0.01150081, -0.00497373, -0.02179473, ..., -0.03089929,
#          -0.00225373, -0.01171216],
#         [ 0.01518836, -0.03275339,  0.00219387, ..., -0.03864972,
#           0.01153866, -0.02452548],
#         [ 0.01494246, -0.03841849, -0.05670143, ..., -0.02217285,
#          -0.02147338, -0.02759386],
#         [ 0.01514984, -0.0137724 , -0.03999642, ..., -0.02247435,
#          -0.0006449 , -0.00080837]], shape=(5, 1024)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [Document(id='a7fd7709-13dd-45ef-8669-36f6002ccaf6', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='cf2462ea-6541-405b-8eaf-c0fbe4e9a5a4', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.')]

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [(Document(id='a7fd7709-13dd-45ef-8669-36f6002ccaf6', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.7010486721992493),
#  (Document(id='cf2462ea-6541-405b-8eaf-c0fbe4e9a5a4', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.8680337071418762)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(id='f0b38b3f-e1c9-4db5-91a3-b3e06fe6c052', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.088742971420288),
#  (Document(id='cf2462ea-6541-405b-8eaf-c0fbe4e9a5a4', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.1538039445877075)]

# %%
# update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='09a39dc6-3ba6-4ea7-927e-fdda591da5e4', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['41fb4b03-b210-43d5-b819-47c05cf904d2',
#   '1abeba72-1b3e-4086-8324-e94d257f276a',
#   'f0b38b3f-e1c9-4db5-91a3-b3e06fe6c052',
#   'a7fd7709-13dd-45ef-8669-36f6002ccaf6',
#   'cf2462ea-6541-405b-8eaf-c0fbe4e9a5a4'],
#  'embeddings': array([[-0.00304607, -0.00076735, -0.01943563, ..., -0.01808811,
#           0.00222509, -0.01835713],
#         [ 0.01150081, -0.00497373, -0.02179473, ..., -0.03089929,
#          -0.00225373, -0.01171216],
#         [ 0.01518836, -0.03275339,  0.00219387, ..., -0.03864972,
#           0.01153866, -0.02452548],
#         [ 0.01494246, -0.03841849, -0.05670143, ..., -0.02217285,
#          -0.02147338, -0.02759386],
#         [ 0.01514984, -0.0137724 , -0.03999642, ..., -0.02247435,
#          -0.0006449 , -0.00080837]], shape=(5, 1024)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# delete document
vector_store.delete(ids=['09a39dc6-3ba6-4ea7-927e-fdda591da5e4'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['41fb4b03-b210-43d5-b819-47c05cf904d2',
#   '1abeba72-1b3e-4086-8324-e94d257f276a',
#   'f0b38b3f-e1c9-4db5-91a3-b3e06fe6c052',
#   'a7fd7709-13dd-45ef-8669-36f6002ccaf6',
#   'cf2462ea-6541-405b-8eaf-c0fbe4e9a5a4'],
#  'embeddings': array([[-0.00304607, -0.00076735, -0.01943563, ..., -0.01808811,
#           0.00222509, -0.01835713],
#         [ 0.01150081, -0.00497373, -0.02179473, ..., -0.03089929,
#          -0.00225373, -0.01171216],
#         [ 0.01518836, -0.03275339,  0.00219387, ..., -0.03864972,
#           0.01153866, -0.02452548],
#         [ 0.01494246, -0.03841849, -0.05670143, ..., -0.02217285,
#          -0.02147338, -0.02759386],
#         [ 0.01514984, -0.0137724 , -0.03999642, ..., -0.02247435,
#          -0.0006449 , -0.00080837]], shape=(5, 1024)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}
